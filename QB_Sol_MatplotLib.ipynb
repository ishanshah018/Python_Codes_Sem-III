# %%
# These cost categories applied to a $9.00 microcontroller:
 # Engineering $1.35
 # Manufacturing $3.60
 # Sales $2.25
 # Profit $1.80
 # Create a  pie chart will show the cost breakdown as different sized pieces.

import matplotlib.pyplot as plt
import numpy as np
data=np.array([1.35,3.6,2.25,1.8])
mylabels=["Engineering","Manufacturing","Sales","Profit"]
plt.pie(data,labels=mylabels)
plt.title("Cost Breakdown of a $9.00 Microcontroller")
# plt.show()

# %%
# Here is how many students got each grade in the recent test:
# A- 4, B-12, C-10, D-2. Plot a pie chart for the student grades in the recent chart with different colors for each student 
# grades and create a wedge for D. Also put a chart title as student's grade history.

data=np.array([4,12,10,2])
mylabels=["A","B","C","D"]
plt.title("Student's Grade History")
plt.pie(data,labels=mylabels,colors=["red","blue","green","yellow"],explode=[0,0,0,0.2])
plt.show()

# %%
#  Imagine you survey your friends to find the kind of movie they like best: Comedy- 4, Action -5, Romance - 6, Drama -1, SciFi - 4. Plot a pie chart for the above survey and use different color for each analysis and create a wedge for action movies. 
# Also put as chart title as "Survey analysis of movie"

data=[4,5,6,1,4]
mylabels=["Comedy","Action","Romance","Drama","SciFi"] 
plt.title("Survey analysis of movie")
plt.pie(data,labels=mylabels,colors=["red","yellow","orange","pink","cyan"],explode=[0,0.2,0,0,0])
plt.show()

# %%
#  Create a Pie Chart using Python Program for the popularity data of different programming languages and displayed it as a 
# pie chart using the Matplotlib Python library. For Python- 29, Java – 19, Javascript – 8, C# - 7, PHP – 6, C,C++ - 5, R – 3. 
# Create an exploded view of python and show the % of each programming language in Pie Chart.

data=[29,19,8,7,6,5,3]
mylabels=["Python","Java","JavaScript","C#","PHP","C,C++","R"]
plt.pie(data,labels=mylabels,autopct="%0.1f%%",explode=[0.2,0,0,0,0,0,0])
plt.show()

# %%
#  Write a python program to create a bar plot of course v/s no. of students using the following dictionary with appropriate 
# labels for X and Y axes and colour of the bars green.
#  Data={‘C’:20,’C++’:15,’Java’:30,’Python’:35}

Data={"C":20,"C++":15,"Java":30,"Python":35}
names=list(Data.keys())
values=list(Data.values())
plt.bar(names,values,color="green")
plt.xlabel("Course")
plt.ylabel("No.of Students")
plt.show()

# %%
#  Create a bar chart for the following dataset:                                                    
# Country = ['USA','Canada','Germany','UK','France']
#  GDP_Per_Capita = [45000,42000,52000,49000,47000]. Also plot title, X-Axis, Y-Axis, different color for each country and 
# the grid should be visible

names= ['USA','Canada','Germany','UK','France']
values= [45000,42000,52000,49000,47000]
plt.xlabel("Country")
plt.ylabel("GDP_Per_Capita ")
plt.title("GDP DATA OF EACH COUNTRY")
plt.grid(True)
plt.bar(names,values,color=["red","orange","green","yellow","black"])
plt.show()

# %%
# A Bar Chart to display employee id numbers on X-axis and their salaries as Y-axis in the form of a bar graph for two 
# departments of a company. There are two departments like sales department and purchase department. For sales 
# department their id's and salaries are mentioned as : x= [1001,1003,1006,1007,1009,1011] and y= [10000, 
# 23000.50,18000.33,16500.5,12000.75, 9999.99] and for purchase department their id's and salaries are mentioned as: 
# x=[1002,1004,1010,1008,1014,1015] and y=[ 5000,6000,4500.5,12000,9000,10000]. Make the chart title as "Microsoft 
# Inc.", x-axis as emplyee id and Y axis as Salary. Use different colors for sales and purchase department.

x1=[1001,1003,1006,1007,1009,1011]
y1=[10000, 23000.50,18000.33,16500.5,12000.75, 9999.99]

x2=[1002,1004,1010,1008,1014,1015]
y2=[ 5000,6000,4500.5,12000,9000,10000]


plt.xlabel("Employee Id")
plt.ylabel("Salaries")
plt.title("Microsoft Inc")

plt.bar(x1,y1,color="orange",label="Sales Department")
plt.bar(x2,y2,color="cyan",label="Purchase Department")
plt.legend()
plt.show()

# %%
#  Write a program to build two bar graphs using subplot function for given two dictionaries in which one graph is in 1st row 
# and another in second row which is horizontal representation of bar graph. 
# D1={“aryan”:66,”bob”:70,”jack”:66,”seema”:34}
#  D2={“joy”:45,”sid”:85,”hina”:90}
#  And also make a title of graph at top as “BAR PLOT”.

D1={"aryan":66,"bob":70,"jack":66,"seema":34}
D2={"joy":45,"sid":85,"hina":90}
plt.suptitle("BAR PLOT")

plt.subplot(2,1,1)
data1=list(D1.keys())
val1=list(D1.values())
plt.barh(data1,val1)

plt.subplot(2,1,2)
data2=list(D2.keys())
val2=list(D2.values())
plt.barh(data2,val2)
plt.show()

# %%
#  A program to display a histogram showing the number of employees in specific age groups. The data is shown: 
# emp_ages=[22,45,30,59,58,56,57,45,43,43,50,40,34,33,25,19] and their bins are [0,10,20,30,40,50,60]. Create a histogram 
# with x-axis label as "emplyee ages" and y axis label as " no. of employees". Create a title of the plot as "Oracle Corp". Also 
# the color of histogram created should be cyan.

age=[22,45,30,59,58,56,57,45,43,43,50,40,34,33,25,19]
bins=[0,10,20,30,40,50,60]
plt.xlabel("Employee Ages")
plt.ylabel("No.of Employees")
plt.title("Oracle Corp")
plt.hist(age,bins,color="cyan",edgecolor="black")
plt.show()

# %%
#  Jeff is a branch manager at a local bank. Recently Jeff’s is receiving customer feedback saying that the wait times for a 
# client to be served by a customer service representative are too long. Jeff decides to observe and write down the time 
# spent by each customer on waiting. Here are his findings from observing and writing down the wait times spent by 20 
# customers (in seconds): 43.1, 35.6, 
# 37.6,36.5,45.3,43.5,40.3,50.2,47.3,31.2,42.2,45.5,30.3,31.4,35.6,45.2,54.1,45.6,36.5,43.1.
#  Plot a histogram for the above data.

data=[43.1, 35.6,37.6,36.5,45.3,43.5,40.3,50.2,47.3,31.2,42.2,45.5,30.3,31.4,35.6,45.2,54.1,45.6,36.5,43.1]
plt.hist(data,edgecolor="black")
plt.xlabel("Time spent by customers(in sec)")
plt.ylabel("No.of Customers")
plt.show()

# %%
#  Uncle Bruno owns a garden with 30 black cherry trees. Each tree is of a different height. The height of the trees (in inches): 
# 61, 63, 64, 66, 68, 69, 71, 71.5, 72, 72.5, 73, 73.5, 74, 74.5, 76, 76.2, 76.5, 77, 77.5, 78, 78.5, 79, 79.2, 80, 81, 82, 83, 84, 85, 
# 87. Plot a histogram with color green, title of the chart should be height of trees along with it’s fontsize as 20.

height=[61,63,64,66,68,69,71,71.5,72,72.5,73,73.5,74,74.5,76,76.2,76.5,77,77.5,78,78.5,79,79.2,80,81,82,83,84,85,87]
plt.hist(height,color="green",edgecolor="black")
plt.title("Height of Trees",fontsize=20,)
plt.show()

# %%
#  A Program to create a line graph to show the profits of a company in  various years. The data is as mentioned: x axis as 
# years and y axis as profits (in Millions). X=[2012,2013,2014,2015,2016,2017] and y = [9,10,10.5,8.8,10.9,9.75]. Plot a line 
# chart with x axis as "Years" and y axis as "Profits (in Millions)" and title of the line chart as "XYZ Company". Also the 
# linestyle should be dashed one.

x=[2012,2013,2014,2015,2016,2017]
y = [9,10,10.5,8.8,10.9,9.75]

plt.plot(x,y,linestyle="--")

plt.xlabel("Years")
plt.ylabel("Profits (in Millions)")
plt.title("XYZ Company")

plt.show()

# %%
#  Prayatna sells designer bags and wallets. During the sales season, he gave discounts ranging from 10% to 50% over a 
# period of 5 weeks. He recorded his sales for each type of discount in an array. Draw a scatter plot to show a relationship 
# between the discount offered and sales made. Take 5 sales in Rupees as user defined values

discounts=[10,20,30,40,50]
sales=[]

for i  in range(5):
    s=float(input(f"Enter sales amount for {discounts[i]}% discount: "))
    sales.append(s)

plt.xlabel("Discount Offered (%)")
plt.ylabel("Sales Amount (Rs)")
plt.scatter(discounts,sales)
plt.show()
# Out:
# Enter sales amount for 10% discount:  500
# Enter sales amount for 20% discount:  2000
# Enter sales amount for 30% discount:  3455
# Enter sales amount for 40% discount:  2300
# Enter sales amount for 50% discount:  1900

# %%
#  Plot a subplot showing the marks of 5 students for 6 subjects (Digital Electronics, Probability and Stochastics, Python, Full 
# Stack Development, IELTS (Reading), and Data Structure). All the marks for each subject and for each student is to be taken 
# user defined. Subplot should be prepared for each subject. Each Subplot should have a title of subject along with a main 
# title of a plot. 


subjects = [
    "Digital Electronics",
    "Probability and Stochastics",
    "Python",
    "Full Stack Development",
    "IELTS (Reading)",
    "Data Structure"
]

students = ["Student 1", "Student 2", "Student 3", "Student 4", "Student 5"]

# Taking user input for marks
marks = []

for i in range(len(subjects)):
    print("Enter marks for", subjects[i])
    subject_marks = []  #To temporary store marks for 1 subject
    for j in range(len(students)):
        mark = int(input(students[j] + ": "))
        subject_marks.append(mark)
    marks.append(subject_marks)

plt.figure(figsize=(10, 12))
plt.suptitle("Marks of Students in Various Subjects")  # Main title

for i in range(6):
    plt.subplot(3, 2, i + 1)  # 3 rows, 2 columns
    plt.bar(students, marks[i], color="blue")
    plt.title(subjects[i])  # Subject title
    plt.ylabel("Marks")

plt.show()
# Out:
# Enter marks for Digital Electronics
# Student 1:  15
# Student 2:  16
# Student 3:  17
# Student 4:  22
# Student 5:  18
# Enter marks for Probability and Stochastics
# Student 1:  18
# Student 2:  23
# Student 3:  21
# Student 4:  19
# Student 5:  15
# Enter marks for Python
# Student 1:  12
# Student 2:  9
# Student 3:  8
# Student 4:  12
# Student 5:  13
# Enter marks for Full Stack Development
# Student 1:  16
# Student 2:  17
# Student 3:  15
# Student 4:  16
# Student 5:  19
# Enter marks for IELTS (Reading)
# Student 1:  22
# Student 2:  21
# Student 3:  12
# Student 4:  15
# Student 5:  14
# Enter marks for Data Structure
# Student 1:  19
# Student 2:  22
# Student 3:  21
# Student 4:  12
# Student 5:  11
